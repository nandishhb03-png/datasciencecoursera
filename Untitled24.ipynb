# %%
name = "Nandeesh"
print(name)
# Out:
# Nandeesh

# %%
cd ~/datasciencecoursera
# Out:
# [WinError 2] The system cannot find the file specified: 'C:\\Users\\nandi/datasciencecoursera'
# C:\Users\nandi

# %%
import os
print(os.listdir(r"C:\Users\nandi"))
# Out:
# ['.anaconda', '.conda', '.condarc', '.continuum', '.idlerc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.keras', '.matplotlib', '.Nandeesh H M {(MSC 1st Year ,DMV assignment)}.ipynb.layout', '.ubuntupro', '.Untitled3.ipynb.layout', '.vscode', '.vscode-shared', 'ai4i2020.csv', 'AI4I2020.ipynb', 'AI4I_Profiling_Report.html', 'AI4I_Report.html', 'airlines.csv', 'anaconda3', 'anaconda_projects', 'ann_tuning', 'AppData', 'Application Data', 'archive (1).zip', 'AU python 2nd unit.ipynb', 'AU PYTHON PROGRAMMING (unit - 1).ipynb', 'AU Python(unit 4).ipynb', 'chandan.ipynb', 'classification of rice (1).xlsx', 'classification_of_rice.csv', 'classification_of_rice.json', 'classifier1.pkl', 'cleve - Copy.mod', 'cleve.mod', 'cleveland.data', 'Contacts', 'Cookies', 'data.pkl', 'Design fuzzy controller.ipynb', 'DMV(unit 4).ipynb', 'DMV.alliance.ipynb', 'Documents', 'dosage_model.pkl', 'Downloads', 'emissions_agriculture_cultivated_organic_soils_e_all_data_norm.csv', 'f2.csv', 'Favorites', 'Fert
# ...

# %%
import os

for root, dirs, files in os.walk(r"C:\Users\nandi"):
    if "datasciencecoursera" in dirs:
        print(os.path.join(root, "datasciencecoursera"))

# %%
# !git clone https://github.com/nandishhb03-png/datasciencecoursera.git
# Out:
# 'git' is not recognized as an internal or external command,
# operable program or batch file.
